# %%
import os
import shutil
from google.colab import drive

# %%
drive.mount('/content/drive')

parent_dir = '/content/drive/My Drive/Colab Notebooks/Testing/Specs'
sub_dirs = ['Ml/train', 'Ms/train', 'Bin/train']
orgin = 'ds'
dest = 'env'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
  
for i in range (1, 1615):
    
    o = os.path.join(parent_dir, sub_dirs[2], orgin, str(i)+'_babble.jpg')
    print(o)
    d = os.path.join(parent_dir, sub_dirs[2], dest, str(i)+'_babble.jpg')
    print(d)
    check = os.path.exists(o)
    print(check)
    if check == True:
      os.rename(o, d)
      print('MOVIEOUS MAXIMUS')
# Out:
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/ds/1_babble.jpg
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/env/1_babble.jpg
# True
# MOVIEOUS MAXIMUS
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/ds/2_babble.jpg
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/env/2_babble.jpg
# True
# MOVIEOUS MAXIMUS
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/ds/3_babble.jpg
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/env/3_babble.jpg
# True
# MOVIEOUS MAXIMUS
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/ds/4_babble.jpg
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/env/4_babble.jpg
# True
# MOVIEOUS MAXIMUS
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/ds/5_babble.jpg
# /content/drive/My Drive/Colab Notebooks/Testing/Specs/Bin/train/env/5_babble.jpg
# False
# ...
