# %%
import os
import matplotlib
import pylab
import librosa
import librosa.display
import numpy as np
from PIL import Image
from google.colab import drive

# %%
drive.mount('/content/drive')

parent_dir = '/content/drive/My Drive/Colab Notebooks/Testing/live'
img_dir = 'spec'
sub_dirs1 = ['indistinct', 'clear_babble']
sub_dirs2 = ['ds', 'bab', 'env']
sub_dirs3 = ['ds','babc','env', 'bab']
audio_dir = 'spilt'
data_split = ['indistinct', 'clear_babble']
data_struct = ['bin','cat3']
tags = ['-ds', '-bab', '-bg']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
audio = os.path.join(parent_dir, audio_dir)
img =  os.path.join(parent_dir, img_dir)

# %%
dimension = 224

max2 = 20

for j in range(1, max2):
    z= j
    file_name = str(z)+ tags[1]
    audio_path = os.path.join(audio,sub_dirs3[2],file_name+'.wav')
    check = os.path.exists(audio_path)
    #if j % 5 == 0:
       # save_path1 = os.path.join(img, data_struct[0], data_split[1],sub_dirs3[1],file_name+'.jpg')
        #save_path2 = os.path.join(img, data_struct[1], data_split[1],sub_dirs1[2],file_name+'.jpg')
        #save_path3 = os.path.join(img, data_struct[2], data_split[1],sub_dirs2[2],file_name+'.jpg')
    #print('Validation set')
    #else:
    save_path1 = os.path.join(img, data_struct[0],sub_dirs2[2],file_name+'.jpg')
    #save_path2 = os.path.join(img, data_struct[1], data_split[0],sub_dirs2[0],file_name+'.jpg')
    save_path2 = os.path.join(img, data_struct[1], data_split[1],sub_dirs2[2],file_name+'.jpg')
    print('Training set')

    if check is True:
        sig, fs = librosa.load(audio_path)
        pylab.axis('off')
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
        S = librosa.feature.melspectrogram(y=sig, sr=fs)
        librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
        pylab.savefig(save_path1, bbox_inches=None, pad_inches=0)
        pylab.close()
        print(audio_path, " has been succesfully converted")##

        im = Image.open(save_path1)
        resize = im.resize((dimension, dimension), Image.ANTIALIAS)
        resize.save(save_path1)
        print(save_path1, " has been succesfully resized")
        
        #sig, fs = librosa.load(audio_path)
        #pylab.axis('off')
        #pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
        #S = librosa.feature.melspectrogram(y=sig, sr=fs)
        #librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
        #pylab.savefig(save_path2, bbox_inches=None, pad_inches=0)
        #pylab.close()
        #print(audio_path, " has been succesfully converted")
        
        #im = Image.open(save_path2)
        #resize = im.resize((dimension, dimension), Image.ANTIALIAS)
        #resize.save(save_path2)
        #print(save_path2, " has been succesfully resized")
        
        sig, fs = librosa.load(audio_path)
        pylab.axis('off')
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
        S = librosa.feature.melspectrogram(y=sig, sr=fs)
        librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
        pylab.savefig(save_path2, bbox_inches=None, pad_inches=0)
        pylab.close()
        print(audio_path, " has been succesfully converted")
        
        
        im = Image.open(save_path2)
        resize = im.resize((dimension, dimension), Image.ANTIALIAS)
        resize.save(save_path2)
        print(save_path3, " has been succesfully resized")
    else:
        print('File does not exist')
# Out:
# Training set
# /content/drive/My Drive/Colab Notebooks/Testing/live/spilt/env/1-bab.wav  has been succesfully converted
# /content/drive/My Drive/Colab Notebooks/Testing/live/spec/bin/env/1-bab.jpg  has been succesfully resized
# /content/drive/My Drive/Colab Notebooks/Testing/live/spilt/env/1-bab.wav  has been succesfully converted
# /content/drive/My Drive/Colab Notebooks/Testing/live/spec/cat3/clear_babble/bab/999-bab.jpg  has been succesfully resized
# Training set
# /content/drive/My Drive/Colab Notebooks/Testing/live/spilt/env/2-bab.wav  has been succesfully converted
# /content/drive/My Drive/Colab Notebooks/Testing/live/spec/bin/env/2-bab.jpg  has been succesfully resized
# /content/drive/My Drive/Colab Notebooks/Testing/live/spilt/env/2-bab.wav  has been succesfully converted
# /content/drive/My Drive/Colab Notebooks/Testing/live/spec/cat3/clear_babble/bab/999-bab.jpg  has been succesfully resized
# Training set
# ...
